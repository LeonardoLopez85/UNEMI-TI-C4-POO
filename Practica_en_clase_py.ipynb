# %% [markdown]
# <a href="https://colab.research.google.com/github/LeonardoLopez85/UNEMI-TI-C4-POO/blob/main/Practica_en_clase_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Crear una clase llamada Persona
class Persona:
  #Crear un metodo llamado constructor para inicializar mis atributos
  def __init__(self,nombre,edad):
    #Crear los atributos de la clase Persona
    self.nombre=nombre
    self.edad=edad
  #Crear un metodo para presentar informacion
  def presentar(self):
    print(f"Hola, me llamo {self.nombre} y tengo {self.edad} años")
#Ingreso de informacion al usuario
nombre=input("Ingrese su nombre: ")
edad=int(input("Ingrese su edad: "))
#Crear un objeto (persona1) a partir de una clase e instanciarla (Persona)
persona1=Persona(nombre,edad)
persona1.presentar()
# Out:
# Ingrese su nombre: Leo
# Ingrese su edad: 41
# Hola, me llamo Leo y tengo 41 años
